# %% [markdown]
# Importing Needed Library

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from tensorflow.python.framework.ops import disable_eager_execution

disable_eager_execution()

# %%
x , y = make_classification(n_samples= 200 , n_features = 4 )
X = pd.DataFrame(data = x)

# %%
ax = sns.pairplot(data = X)

# %%
model = keras.Sequential(
    [
        keras.layers.Dense(32 , input_shape = (4, ) , activation = "relu" ),
        keras.layers.Dense(128 , activation = "relu" ),
        keras.layers.Dense(10 , activation = "relu" ),
        keras.layers.Dense(3 , activation = "sigmoid" ),
        
    ]
)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(x,y,epochs=50)
# Out:
# Train on 200 samples
# Epoch 1/50
# 200/200 [==============================] - 0s 411us/sample - loss: 1.0709 - accuracy: 0.5100
# Epoch 2/50
# 200/200 [==============================] - 0s 95us/sample - loss: 1.0074 - accuracy: 0.8400
# Epoch 3/50
# 200/200 [==============================] - 0s 100us/sample - loss: 0.9506 - accuracy: 0.8650
# Epoch 4/50
# 200/200 [==============================] - 0s 90us/sample - loss: 0.8950 - accuracy: 0.8900
# Epoch 5/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.8438 - accuracy: 0.9050
# Epoch 6/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.7976 - accuracy: 0.9300
# Epoch 7/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.7581 - accuracy: 0.9400
# Epoch 8/50
# 200/200 [==============================] - 0s 90us/sample - loss: 0.7258 - accuracy: 0.9350
# Epoch 9/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6987 - accuracy: 0.9250
# Epoch 10/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6775 - accuracy: 0.9350
# Epoch 11/50
# 200/200 [==============================] - 0s 90us/sample - loss: 0.6592 - accuracy: 0.9400
# Epoch 12/50
# 200/200 [==============================] - 0s 90us/sample - loss: 0.6432 - accuracy: 0.9400
# Epoch 13/50
# 200/200 [==============================] - 0s 90us/sample - loss: 0.6321 - accuracy: 0.9400
# Epoch 14/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6275 - accuracy: 0.9400
# Epoch 15/50
# 200/200 [==============================] - 0s 95us/sample - loss: 0.6206 - accuracy: 0.9450
# Epoch 16/50
# 200/200 [==============================] - 0s 90us/sample - loss: 0.6176 - accuracy: 0.9400
# Epoch 17/50
# 200/200 [==============================] - 0s 90us/sample - loss: 0.6145 - accuracy: 0.9450
# Epoch 18/50
# 200/200 [==============================] - 0s 95us/sample - loss: 0.6133 - accuracy: 0.9450
# Epoch 19/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6120 - accuracy: 0.9450
# Epoch 20/50
# 200/200 [==============================] - 0s 90us/sample - loss: 0.6107 - accuracy: 0.9400
# Epoch 21/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6104 - accuracy: 0.9400
# Epoch 22/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6092 - accuracy: 0.9400
# Epoch 23/50
# 200/200 [==============================] - 0s 90us/sample - loss: 0.6086 - accuracy: 0.9350
# Epoch 24/50
# 200/200 [==============================] - 0s 75us/sample - loss: 0.6073 - accuracy: 0.9400
# Epoch 25/50
# 200/200 [==============================] - 0s 80us/sample - loss: 0.6069 - accuracy: 0.9350
# Epoch 26/50
# 200/200 [==============================] - 0s 80us/sample - loss: 0.6066 - accuracy: 0.9350
# Epoch 27/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6061 - accuracy: 0.9350
# Epoch 28/50
# 200/200 [==============================] - 0s 80us/sample - loss: 0.6058 - accuracy: 0.9400
# Epoch 29/50
# 200/200 [==============================] - 0s 80us/sample - loss: 0.6056 - accuracy: 0.9350
# Epoch 30/50
# 200/200 [==============================] - 0s 80us/sample - loss: 0.6049 - accuracy: 0.9350
# Epoch 31/50
# 200/200 [==============================] - 0s 75us/sample - loss: 0.6050 - accuracy: 0.9400
# Epoch 32/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6047 - accuracy: 0.9400
# Epoch 33/50
# 200/200 [==============================] - 0s 70us/sample - loss: 0.6045 - accuracy: 0.9400
# Epoch 34/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6043 - accuracy: 0.9350
# Epoch 35/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6045 - accuracy: 0.9350
# Epoch 36/50
# 200/200 [==============================] - 0s 70us/sample - loss: 0.6039 - accuracy: 0.9350
# Epoch 37/50
# 200/200 [==============================] - 0s 80us/sample - loss: 0.6062 - accuracy: 0.9400
# Epoch 38/50
# 200/200 [==============================] - 0s 75us/sample - loss: 0.6034 - accuracy: 0.9400
# Epoch 39/50
# 200/200 [==============================] - 0s 70us/sample - loss: 0.6025 - accuracy: 0.9400
# Epoch 40/50
# 200/200 [==============================] - 0s 75us/sample - loss: 0.6043 - accuracy: 0.9450
# Epoch 41/50
# 200/200 [==============================] - 0s 80us/sample - loss: 0.6054 - accuracy: 0.9450
# Epoch 42/50
# 200/200 [==============================] - 0s 80us/sample - loss: 0.6037 - accuracy: 0.9450
# Epoch 43/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6023 - accuracy: 0.9400
# Epoch 44/50
# 200/200 [==============================] - 0s 90us/sample - loss: 0.6024 - accuracy: 0.9350
# Epoch 45/50
# 200/200 [==============================] - 0s 90us/sample - loss: 0.6021 - accuracy: 0.9400
# Epoch 46/50
# 200/200 [==============================] - 0s 90us/sample - loss: 0.6031 - accuracy: 0.9400
# Epoch 47/50
# 200/200 [==============================] - 0s 80us/sample - loss: 0.6027 - accuracy: 0.9400
# Epoch 48/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6018 - accuracy: 0.9400
# Epoch 49/50
# 200/200 [==============================] - 0s 80us/sample - loss: 0.6014 - accuracy: 0.9450
# Epoch 50/50
# 200/200 [==============================] - 0s 85us/sample - loss: 0.6016 - accuracy: 0.9400
